# %% [markdown]
# # Operadores Relacionais

# %% [markdown]
# ##> Maior
# ##>= Maior igual
# ##< Menor
# ##<= Menor igual
# ##!= Diferente
# ##==Igual

# %%
10 > 20 # 10 é maior que 20
# Out:
# False

# %%
10 < 20 # 10 é menor que 20
# Out:
# True

# %%
5+1 != 6 # 5+1 é diferente de 6
# Out:
# False

# %%
3+1 != 6 # 3+1 é maior ou igual a 4
# Out:
# True

# %%
nome_aluno = "amdre"
nome_professor = "adeb"

# %%
nome_aluno == nome_professor
# Out:
# False

# %%
10 != 20
# Out:
# True

# %% [markdown]
# # Operadores Lógicos

# %% [markdown]
# *   AND (e)
# *   OR (ou)
# *   NOT (negação)

# %% [markdown]
# ### AND
#
# True + True = True
# True + False = False
# False + True = False
# False + False = False

# %%
(10>20) and (20>30)
# Out:
# False

# %%
(10<20) and(20 <30)
# Out:
# True

# %% [markdown]
# ### OR
#
# True + True = True
# True + False = True
# False + True = True
# False + False = False

# %%
(1 < 2) or (3 >)
# Out:
# True

# %%
"João" == "João" or "Python" != "python"
# Out:
# True

# %% [markdown]
# ### Not
#
# not True = False not False = True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True
